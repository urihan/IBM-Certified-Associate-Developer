# %% [markdown]
# # Single Qubit Gates
# ## Quick review on :
# - The Pauli Gates (XYZ)
# - Hadamard Gates
# - P-gate
# - I,S,T-gates
# - U-gate

# %%
from qiskit import QuantumCircuit, assemble, Aer, execute
from math import pi,sqrt
from qiskit.visualization import plot_bloch_multivector, plot_histogram
sim = Aer.get_backend('aer_simulator')

# %% [markdown]
# ### Pauli Gates
#
# #### X Gate

# %%
qc = QuantumCircuit(1)
qc.x(0)
qc.draw(output = 'mpl')

# %%
qc.save_statevector()
qobj = assemble(qc)
state = sim.run(qobj).result().get_statevector()
plot_bloch_multivector(state)

# %% [markdown]
# #### Y Gate & Z Gate

# %%
qc.y(0)
qc.z(0)
qc.draw(output = 'mpl')

# %% [markdown]
# - Z Gate : Identity matrix but spits out a negative sign on a state 1
# - Y Gate : Matrix with i and reverse order of identity matrix

# %% [markdown]
# #### RX, RY Gate

# %% [markdown]
# - RX Gate : Rotation around x-axis

# %%
qc = QuantumCircuit(1)
qc.rx(0 , 0)
qc.draw(output = 'mpl')

# %%
qc.save_statevector()
qobj = assemble(qc)
state = sim.run(qobj).result().get_statevector()
plot_bloch_multivector(state)

# %% [markdown]
# - RY Gate : Rotation around y-axis

# %%
qc = QuantumCircuit(1)
qc.ry(-pi/2 , 0)
qc.draw(output = 'mpl')

# %%
qc.save_statevector()
qobj = assemble(qc)
state = sim.run(qobj).result().get_statevector()
plot_bloch_multivector(state)

# %%
qc = QuantumCircuit(1)
qc.rz(0 , 0)
qc.draw(output = 'mpl')

# %%
qc.save_statevector()
qobj = assemble(qc)
state = sim.run(qobj).result().get_statevector()
plot_bloch_multivector(state)

# %%
qc = QuantumCircuit(1,1)
# qc.rx(pi/2, 0)
# qc.h(0)
qc.rx(pi/2, 0)
# qc.rz(-pi / 2, 0)
# qc.ry(pi, 0)
qc.draw(output = 'mpl')

# %%
simulator = Aer.get_backend('statevector_simulator')
job = execute(qc, simulator)
result = job.result()
outputstate = result.get_statevector(qc) 
plot_bloch_multivector(outputstate)
