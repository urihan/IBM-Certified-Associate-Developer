# %%
import qiskit

# %%
quantum_circuit = qiskit.circuit.library.QuantumVolume(5)
quantum_circuit.measure_all()
quantum_circuit.draw()
# Out:
#         ┌───────────────────────────┐ ░ ┌─┐
#    q_0: ┤0                          ├─░─┤M├────────────
#         │                           │ ░ └╥┘┌─┐
#    q_1: ┤1                          ├─░──╫─┤M├─────────
#         │                           │ ░  ║ └╥┘┌─┐
#    q_2: ┤2 quantum_volume_[5,5,105] ├─░──╫──╫─┤M├──────
#         │                           │ ░  ║  ║ └╥┘┌─┐
#    q_3: ┤3                          ├─░──╫──╫──╫─┤M├───
#         │                           │ ░  ║  ║  ║ └╥┘┌─┐
#    q_4: ┤4                          ├─░──╫──╫──╫──╫─┤M├
#         └───────────────────────────┘ ░  ║  ║  ║  ║ └╥┘
# meas_0: ═════════════════════════════════╩══╬══╬══╬══╬═
#                                             ║  ║  ║  ║
# meas_1: ════════════════════════════════════╩══╬══╬══╬═
#                                                ║  ║  ║
# meas_2: ═══════════════════════════════════════╩══╬══╬═
#                                                   ║  ║
# meas_3: ══════════════════════════════════════════╩══╬═
#                                                      ║
# meas_4: ═════════════════════════════════════════════╩═

# %%
# prepare your circuit to run
from qiskit import IBMQ

# %%
# Get the API token in
# https://quantum-computing.ibm.com/
IBMQ.save_account("9d52e0750843e5ed985753dfe8dee81f4b1a34b9a1b39b9d076876756ae1ca1ec21717920791a12c2c6779bbe9d18ac33617d79b2b3bbe5bc063f0ec1e22b902", overwrite = True)

# %%
provider = IBMQ.load_account()
backend = provider.get_backend('ibmq_quito')

# %%
optimized_circuit = qiskit.transpile(quantum_circuit, backend)
optimized_circuit.draw()
# Out:
# global phase: 6.0258
#           ┌────────────┐ ┌────┐┌─────────────┐ ┌────┐ ┌───────────┐       »
# q_2 -> 0 ─┤ Rz(1.0935) ├─┤ √X ├┤ Rz(-1.5093) ├─┤ √X ├─┤ Rz(2.041) ├────■──»
#          ┌┴────────────┴┐├────┤├─────────────┤ ├────┤┌┴───────────┴─┐┌─┴─┐»
# q_1 -> 1 ┤ Rz(-0.60789) ├┤ √X ├┤ Rz(-2.3594) ├─┤ √X ├┤ Rz(-0.11679) ├┤ X ├»
#          └┬────────────┬┘├────┤├─────────────┴┐├────┤├─────────────┬┘└───┘»
# q_4 -> 2 ─┤ Rz(1.6351) ├─┤ √X ├┤ Rz(-0.97355) ├┤ √X ├┤ Rz(0.41957) ├──────»
#          ┌┴────────────┤ ├────┤├──────────────┤├────┤├─────────────┤      »
# q_0 -> 3 ┤ Rz(0.68206) ├─┤ √X ├┤ Rz(-0.18054) ├┤ √X ├┤ Rz(0.26489) ├───■──»
#          └┬────────────┤ ├────┤├─────────────┬┘├────┤└┬───────────┬┘ ┌─┴─┐»
# q_3 -> 4 ─┤ Rz(1.1699) ├─┤ √X ├┤ Rz(-1.7586) ├─┤ √X ├─┤ Rz(3.028) ├──┤ X ├»
#           └────────────┘ └────┘└─────────────┘ └────┘ └───────────┘  └───┘»
#  meas_0: ═════════════════════════════════════════════════════════════════»
#                                                                           »
#  meas_1: ═════════════════════════════════════════════════════════════════»
#                                                                           »
#  meas_2: ═════════════════════════════════════════════════════════════════»
#                                                                           »
#  meas_3: ═════════════════════════════════════════════════════════════════»
#                                                                           »
#  meas_4: ═════════════════════════════════════════════════════════════════»
#                                                                           »
# «              ┌────┐     ┌─────────────┐          ┌────┐         »
# «q_2 -> 0 ─────┤ √X ├─────┤ Rz(-3.1374) ├──■───────┤ √X ├──────■──»
# «          ┌───┴────┴───┐ └─────────────┘┌─┴─┐┌────┴────┴───┐┌─┴─┐»
# «q_1 -> 1 ─┤ Rz(1.0357) ├────────────────┤ X ├┤ Rz(0.41028) ├┤ X ├»
# «          └────────────┘                └───┘└─────────────┘└───┘»
# «q_4 -> 2 ────────────────────────────────────────────────────────»
# «              ┌────┐     ┌─────────────┐          ┌────┐         »
# «q_0 -> 3 ─────┤ √X ├─────┤ Rz(-2.7761) ├──■───────┤ √X ├──────■──»
# «         ┌────┴────┴────┐└─────────────┘┌─┴─┐┌────┴────┴───┐┌─┴─┐»
# «q_3 -> 4 ┤ Rz(-0.81354) ├───────────────┤ X ├┤ Rz(0.40667) ├┤ X ├»
# «         └──────────────┘               └───┘└─────────────┘└───┘»
# « meas_0: ════════════════════════════════════════════════════════»
# «                                                                 »
# « meas_1: ════════════════════════════════════════════════════════»
# «                                                                 »
# « meas_2: ════════════════════════════════════════════════════════»
# «                                                                 »
# « meas_3: ════════════════════════════════════════════════════════»
# «                                                                 »
# « meas_4: ════════════════════════════════════════════════════════»
# «                                                                 »
# «          ┌────────────┐┌────┐┌─────────────┐ ┌────┐┌─────────────┐     »
# «q_2 -> 0 ─┤ Rz(2.6485) ├┤ √X ├┤ Rz(-1.7392) ├─┤ √X ├┤ Rz(-1.4485) ├─────»
# «         ┌┴────────────┤├────┤├─────────────┴┐├────┤└┬───────────┬┘┌───┐»
# «q_1 -> 1 ┤ Rz(-2.4397) ├┤ √X ├┤ Rz(-0.92282) ├┤ √X ├─┤ Rz(2.577) ├─┤ X ├»
# «         └─────────────┘└────┘└──────────────┘└────┘ └───────────┘ └─┬─┘»
# «q_4 -> 2 ────────────────────────────────────────────────────────────■──»
# «         ┌─────────────┐┌────┐┌─────────────┐ ┌────┐ ┌────────────┐     »
# «q_0 -> 3 ┤ Rz(-2.7456) ├┤ √X ├┤ Rz(-2.3057) ├─┤ √X ├─┤ Rz(1.5041) ├─────»
# «         ├─────────────┤├────┤├─────────────┤ ├────┤┌┴────────────┤     »
# «q_3 -> 4 ┤ Rz(0.99661) ├┤ √X ├┤ Rz(-2.1331) ├─┤ √X ├┤ Rz(-0.8525) ├─────»
# «         └─────────────┘└────┘└─────────────┘ └────┘└─────────────┘     »
# « meas_0: ═══════════════════════════════════════════════════════════════»
# «                                                                        »
# « meas_1: ═══════════════════════════════════════════════════════════════»
# «                                                                        »
# « meas_2: ═══════════════════════════════════════════════════════════════»
# «                                                                        »
# « meas_3: ═══════════════════════════════════════════════════════════════»
# «                                                                        »
# « meas_4: ═══════════════════════════════════════════════════════════════»
# «                                                                        »
# «                                                                              »
# «q_2 -> 0 ─────────────────────────────────────────────────────────────────────»
# «         ┌─────────────┐               ┌───┐┌─────────────┐┌───┐ ┌──────────┐ »
# «q_1 -> 1 ┤ Rz(0.95968) ├───────────────┤ X ├┤ Rz(0.24313) ├┤ X ├─┤ Rz(2.38) ├─»
# «         └────┬────┬───┘┌─────────────┐└─┬─┘└────┬────┬───┘└─┬─┘┌┴──────────┴┐»
# «q_4 -> 2 ─────┤ √X ├────┤ Rz(-2.8935) ├──■───────┤ √X ├──────■──┤ Rz(1.5163) ├»
# «              └────┘    └─────────────┘          └────┘         └────────────┘»
# «q_0 -> 3 ─────────────────────────────────────────────────────────────────────»
# «                                                                              »
# «q_3 -> 4 ─────────────────────────────────────────────────────────────────────»
# «                                                                              »
# « meas_0: ═════════════════════════════════════════════════════════════════════»
# «                                                                              »
# « meas_1: ═════════════════════════════════════════════════════════════════════»
# «                                                                              »
# « meas_2: ═════════════════════════════════════════════════════════════════════»
# «                                                                              »
# « meas_3: ═════════════════════════════════════════════════════════════════════»
# «                                                                              »
# « meas_4: ═════════════════════════════════════════════════════════════════════»
# «                                                                              »
# «                                                                  »
# «q_2 -> 0 ─────────────────────────────────────────────────────────»
# «         ┌────┐┌─────────────┐┌────┐ ┌────────────┐     ┌───┐     »
# «q_1 -> 1 ┤ √X ├┤ Rz(-2.0245) ├┤ √X ├─┤ Rz(2.4061) ├──■──┤ X ├──■──»
# «         ├────┤└┬────────────┤├────┤┌┴────────────┤  │  └─┬─┘  │  »
# «q_4 -> 2 ┤ √X ├─┤ Rz(-2.907) ├┤ √X ├┤ Rz(-1.9402) ├──┼────┼────┼──»
# «         └────┘ └────────────┘└────┘└─────────────┘┌─┴─┐  │  ┌─┴─┐»
# «q_0 -> 3 ──────────────────────────────────────────┤ X ├──■──┤ X ├»
# «                                                   └───┘     └───┘»
# «q_3 -> 4 ─────────────────────────────────────────────────────────»
# «                                                                  »
# « meas_0: ═════════════════════════════════════════════════════════»
# «                                                                  »
# « meas_1: ═════════════════════════════════════════════════════════»
# «                                                                  »
# « meas_2: ═════════════════════════════════════════════════════════»
# «                                                                  »
# « meas_3: ═════════════════════════════════════════════════════════»
# «                                                                  »
# « meas_4: ═════════════════════════════════════════════════════════»
# «                                                                  »
# «                                                                         »
# «q_2 -> 0 ─────────────────────────────────────────────────────────────■──»
# «          ┌────────────┐┌────┐┌──────────────┐┌────┐┌─────────────┐ ┌─┴─┐»
# «q_1 -> 1 ─┤ Rz(1.6351) ├┤ √X ├┤ Rz(-0.97355) ├┤ √X ├┤ Rz(-1.1512) ├─┤ X ├»
# «          └────────────┘└────┘└──────────────┘└────┘└─────────────┘ └───┘»
# «q_4 -> 2 ────────────────────────────────────────────────────────────────»
# «         ┌─────────────┐┌────┐ ┌───────────┐  ┌────┐┌──────────────┐     »
# «q_0 -> 3 ┤ Rz(-2.5053) ├┤ √X ├─┤ Rz(-2.54) ├──┤ √X ├┤ Rz(0.031544) ├─────»
# «         └─────────────┘└────┘ └───────────┘  └────┘└──────────────┘     »
# «q_3 -> 4 ────────────────────────────────────────────────────────────────»
# «                                                                         »
# « meas_0: ════════════════════════════════════════════════════════════════»
# «                                                                         »
# « meas_1: ════════════════════════════════════════════════════════════════»
# «                                                                         »
# « meas_2: ════════════════════════════════════════════════════════════════»
# «                                                                         »
# « meas_3: ════════════════════════════════════════════════════════════════»
# «                                                                         »
# « meas_4: ════════════════════════════════════════════════════════════════»
# «                                                                         »
# «              ┌────┐    ┌─────────────┐          ┌────┐         ┌────────────┐»
# «q_2 -> 0 ─────┤ √X ├────┤ Rz(-2.8935) ├──■───────┤ √X ├──────■──┤ Rz(2.7116) ├»
# «         ┌────┴────┴───┐└─────────────┘┌─┴─┐┌────┴────┴───┐┌─┴─┐├───────────┬┘»
# «q_1 -> 1 ┤ Rz(0.95968) ├───────────────┤ X ├┤ Rz(0.24313) ├┤ X ├┤ Rz(-2.74) ├─»
# «         └─────────────┘               └───┘└─────────────┘└───┘└───────────┘ »
# «q_4 -> 2 ─────────────────────────────────────────────────────────────────────»
# «                                                                              »
# «q_0 -> 3 ─────────────────────────────────────────────────────────────────────»
# «                                                                              »
# «q_3 -> 4 ─────────────────────────────────────────────────────────────────────»
# «                                                                              »
# « meas_0: ═════════════════════════════════════════════════════════════════════»
# «                                                                              »
# « meas_1: ═════════════════════════════════════════════════════════════════════»
# «                                                                              »
# « meas_2: ═════════════════════════════════════════════════════════════════════»
# «                                                                              »
# « meas_3: ═════════════════════════════════════════════════════════════════════»
# «                                                                              »
# « meas_4: ═════════════════════════════════════════════════════════════════════»
# «                                                                              »
# «         ┌────┐┌─────────────┐┌────┐┌────────────┐                    »
# «q_2 -> 0 ┤ √X ├┤ Rz(-1.5616) ├┤ √X ├┤ Rz(2.5806) ├────────────────────»
# «         ├────┤├─────────────┤├────┤├────────────┤          ┌────┐    »
# «q_1 -> 1 ┤ √X ├┤ Rz(-2.2924) ├┤ √X ├┤ Rz(1.4306) ├──■───────┤ √X ├────»
# «         └────┘└─────────────┘└────┘└────────────┘  │       └────┘    »
# «q_4 -> 2 ───────────────────────────────────────────┼─────────────────»
# «                                                  ┌─┴─┐┌─────────────┐»
# «q_0 -> 3 ─────────────────────────────────────────┤ X ├┤ Rz(0.63535) ├»
# «                                                  └───┘└─────────────┘»
# «q_3 -> 4 ─────────────────────────────────────────────────────────────»
# «                                                                      »
# « meas_0: ═════════════════════════════════════════════════════════════»
# «                                                                      »
# « meas_1: ═════════════════════════════════════════════════════════════»
# «                                                                      »
# « meas_2: ═════════════════════════════════════════════════════════════»
# «                                                                      »
# « meas_3: ═════════════════════════════════════════════════════════════»
# «                                                                      »
# « meas_4: ═════════════════════════════════════════════════════════════»
# «                                                                      »
# «                                                                       »
# «q_2 -> 0 ──────────────────────────────────────────────────────────────»
# «         ┌─────────────┐          ┌────┐         ┌──────────────┐┌────┐»
# «q_1 -> 1 ┤ Rz(-2.7859) ├──■───────┤ √X ├──────■──┤ Rz(-0.25152) ├┤ √X ├»
# «         └─────────────┘  │       └────┘      │  └──────────────┘└────┘»
# «q_4 -> 2 ─────────────────┼───────────────────┼────────────────────────»
# «                        ┌─┴─┐┌─────────────┐┌─┴─┐┌─────────────┐ ┌────┐»
# «q_0 -> 3 ───────────────┤ X ├┤ Rz(0.14424) ├┤ X ├┤ Rz(-2.0444) ├─┤ √X ├»
# «                        └───┘└─────────────┘└───┘└─────────────┘ └────┘»
# «q_3 -> 4 ──────────────────────────────────────────────────────────────»
# «                                                                       »
# « meas_0: ══════════════════════════════════════════════════════════════»
# «                                                                       »
# « meas_1: ══════════════════════════════════════════════════════════════»
# «                                                                       »
# « meas_2: ══════════════════════════════════════════════════════════════»
# «                                                                       »
# « meas_3: ══════════════════════════════════════════════════════════════»
# «                                                                       »
# « meas_4: ══════════════════════════════════════════════════════════════»
# «                                                                       »
# «                                                                          »
# «q_2 -> 0 ─────────────────────────────────────────────────────────────────»
# «         ┌─────────────┐┌────┐┌────────────┐                              »
# «q_1 -> 1 ┤ Rz(-1.5569) ├┤ √X ├┤ Rz(3.0648) ├──────────────────────■───────»
# «         └─────────────┘└────┘└────────────┘                      │       »
# «q_4 -> 2 ─────────────────────────────────────────────────────────┼───────»
# «         ┌─────────────┐┌────┐┌───────────┐      ┌───┐          ┌─┴─┐     »
# «q_0 -> 3 ┤ Rz(-1.3848) ├┤ √X ├┤ Rz(1.837) ├───■──┤ X ├──■───────┤ X ├─────»
# «         └─────────────┘└────┘└───────────┘ ┌─┴─┐└─┬─┘┌─┴─┐┌────┴───┴────┐»
# «q_3 -> 4 ───────────────────────────────────┤ X ├──■──┤ X ├┤ Rz(0.98409) ├»
# «                                            └───┘     └───┘└─────────────┘»
# « meas_0: ═════════════════════════════════════════════════════════════════»
# «                                                                          »
# « meas_1: ═════════════════════════════════════════════════════════════════»
# «                                                                          »
# « meas_2: ═════════════════════════════════════════════════════════════════»
# «                                                                          »
# « meas_3: ═════════════════════════════════════════════════════════════════»
# «                                                                          »
# « meas_4: ═════════════════════════════════════════════════════════════════»
# «                                                                          »
# «                                                                             »
# «q_2 -> 0 ────────────────────────────────────────────────────────────────────»
# «         ┌───┐                 ┌─────────────┐     ┌────┐    ┌──────────────┐»
# «q_1 -> 1 ┤ X ├────────■────────┤ Rz(-2.6404) ├─────┤ √X ├────┤ Rz(-0.30065) ├»
# «         └─┬─┘        │        └─────────────┘     └────┘    └──────────────┘»
# «q_4 -> 2 ──┼──────────┼──────────────────────────────────────────────────────»
# «           │        ┌─┴─┐       ┌────────────┐     ┌────┐    ┌─────────────┐ »
# «q_0 -> 3 ──■────────┤ X ├───────┤ Rz(-1.568) ├─────┤ √X ├────┤ Rz(-1.4571) ├─»
# «         ┌────┐┌────┴───┴─────┐ └───┬────┬───┘┌────┴────┴───┐└─────────────┘ »
# «q_3 -> 4 ┤ √X ├┤ Rz(-0.68054) ├─────┤ √X ├────┤ Rz(-2.0903) ├────────────────»
# «         └────┘└──────────────┘     └────┘    └─────────────┘                »
# « meas_0: ════════════════════════════════════════════════════════════════════»
# «                                                                             »
# « meas_1: ════════════════════════════════════════════════════════════════════»
# «                                                                             »
# « meas_2: ════════════════════════════════════════════════════════════════════»
# «                                                                             »
# « meas_3: ════════════════════════════════════════════════════════════════════»
# «                                                                             »
# « meas_4: ════════════════════════════════════════════════════════════════════»
# «                                                                             »
# «                                                                      »
# «q_2 -> 0 ─────────────────────────────────────────────────────────────»
# «         ┌────┐┌─────────────┐┌───┐┌─────────────┐               ┌───┐»
# «q_1 -> 1 ┤ √X ├┤ Rz(-2.9123) ├┤ X ├┤ Rz(-0.5238) ├───────────────┤ X ├»
# «         └────┘└─────────────┘└─┬─┘└────┬────┬───┘┌─────────────┐└─┬─┘»
# «q_4 -> 2 ───────────────────────■───────┤ √X ├────┤ Rz(-2.6129) ├──■──»
# «         ┌────┐┌─────────────┐          └────┘    └─────────────┘     »
# «q_0 -> 3 ┤ √X ├┤ Rz(-2.3517) ├────────────────────────────────────────»
# «         └────┘└─────────────┘                                        »
# «q_3 -> 4 ─────────────────────────────────────────────────────────────»
# «                                                                      »
# « meas_0: ═════════════════════════════════════════════════════════════»
# «                                                                      »
# « meas_1: ═════════════════════════════════════════════════════════════»
# «                                                                      »
# « meas_2: ═════════════════════════════════════════════════════════════»
# «                                                                      »
# « meas_3: ═════════════════════════════════════════════════════════════»
# «                                                                      »
# « meas_4: ═════════════════════════════════════════════════════════════»
# «                                                                      »
# «                                                                      »
# «q_2 -> 0 ─────────────────────────────────────────────────────────────»
# «         ┌────────────┐┌───┐ ┌────────────┐┌────┐┌─────────────┐┌────┐»
# «q_1 -> 1 ┤ Rz(0.1653) ├┤ X ├─┤ Rz(2.5592) ├┤ √X ├┤ Rz(-2.2859) ├┤ √X ├»
# «         └───┬────┬───┘└─┬─┘┌┴────────────┤├────┤├─────────────┤├────┤»
# «q_4 -> 2 ────┤ √X ├──────■──┤ Rz(-1.1981) ├┤ √X ├┤ Rz(-1.7366) ├┤ √X ├»
# «             └────┘         └─────────────┘└────┘└─────────────┘└────┘»
# «q_0 -> 3 ─────────────────────────────────────────────────────────────»
# «                                                                      »
# «q_3 -> 4 ─────────────────────────────────────────────────────────────»
# «                                                                      »
# « meas_0: ═════════════════════════════════════════════════════════════»
# «                                                                      »
# « meas_1: ═════════════════════════════════════════════════════════════»
# «                                                                      »
# « meas_2: ═════════════════════════════════════════════════════════════»
# «                                                                      »
# « meas_3: ═════════════════════════════════════════════════════════════»
# «                                                                      »
# « meas_4: ═════════════════════════════════════════════════════════════»
# «                                                                      »
# «                                   ┌────┐    ┌─────────────┐     »
# «q_2 -> 0 ──────────────────■───────┤ √X ├────┤ Rz(-3.1039) ├──■──»
# «         ┌──────────────┐┌─┴─┐┌────┴────┴───┐└─────────────┘┌─┴─┐»
# «q_1 -> 1 ┤ Rz(-0.68366) ├┤ X ├┤ Rz(0.50557) ├───────────────┤ X ├»
# «         ├─────────────┬┘└───┘└─────────────┘               └───┘»
# «q_4 -> 2 ┤ Rz(-2.2968) ├─────────────────────────────────────────»
# «         └─────────────┘                                         »
# «q_0 -> 3 ────────────────────────────────────────────────────────»
# «                                                                 »
# «q_3 -> 4 ────────────────────────────────────────────────────────»
# «                                                                 »
# « meas_0: ════════════════════════════════════════════════════════»
# «                                                                 »
# « meas_1: ════════════════════════════════════════════════════════»
# «                                                                 »
# « meas_2: ════════════════════════════════════════════════════════»
# «                                                                 »
# « meas_3: ════════════════════════════════════════════════════════»
# «                                                                 »
# « meas_4: ════════════════════════════════════════════════════════»
# «                                                                 »
# «              ┌────┐          ┌────────────┐┌────┐┌─────────────┐ ┌────┐»
# «q_2 -> 0 ─────┤ √X ├──────■───┤ Rz(1.4359) ├┤ √X ├┤ Rz(-2.8481) ├─┤ √X ├»
# «         ┌────┴────┴───┐┌─┴─┐┌┴────────────┤├────┤├─────────────┴┐├────┤»
# «q_1 -> 1 ┤ Rz(0.21374) ├┤ X ├┤ Rz(-1.5991) ├┤ √X ├┤ Rz(-0.24723) ├┤ √X ├»
# «         └─────────────┘└───┘└─────────────┘└────┘└──────────────┘└────┘»
# «q_4 -> 2 ───────────────────────────────────────────────────────────────»
# «                                                                        »
# «q_0 -> 3 ───────────────────────────────────────────────────────────────»
# «                                                                        »
# «q_3 -> 4 ───────────────────────────────────────────────────────────────»
# «                                                                        »
# « meas_0: ═══════════════════════════════════════════════════════════════»
# «                                                                        »
# « meas_1: ═══════════════════════════════════════════════════════════════»
# «                                                                        »
# « meas_2: ═══════════════════════════════════════════════════════════════»
# «                                                                        »
# « meas_3: ═══════════════════════════════════════════════════════════════»
# «                                                                        »
# « meas_4: ═══════════════════════════════════════════════════════════════»
# «                                                                        »
# «          ┌────────────┐                                                     »
# «q_2 -> 0 ─┤ Rz(-3.113) ├─────────────────────────────────────────────────────»
# «         ┌┴────────────┴┐┌───┐     ┌───┐┌──────────────┐┌────┐┌─────────────┐»
# «q_1 -> 1 ┤ Rz(-0.70855) ├┤ X ├──■──┤ X ├┤ Rz(-0.87418) ├┤ √X ├┤ Rz(-1.8877) ├»
# «         └──────────────┘└─┬─┘┌─┴─┐└─┬─┘├─────────────┬┘├────┤├─────────────┤»
# «q_4 -> 2 ──────────────────■──┤ X ├──■──┤ Rz(-1.0209) ├─┤ √X ├┤ Rz(-2.1694) ├»
# «                              └───┘     └─────────────┘ └────┘└─────────────┘»
# «q_0 -> 3 ────────────────────────────────────────────────────────────────────»
# «                                                                             »
# «q_3 -> 4 ────────────────────────────────────────────────────────────────────»
# «                                                                             »
# « meas_0: ════════════════════════════════════════════════════════════════════»
# «                                                                             »
# « meas_1: ════════════════════════════════════════════════════════════════════»
# «                                                                             »
# « meas_2: ════════════════════════════════════════════════════════════════════»
# «                                                                             »
# « meas_3: ════════════════════════════════════════════════════════════════════»
# «                                                                             »
# « meas_4: ════════════════════════════════════════════════════════════════════»
# «                                                                             »
# «                                                                      »
# «q_2 -> 0 ─────────────────────────────────────────────────────────────»
# «         ┌────┐┌─────────────┐          ┌────┐    ┌─────────────┐     »
# «q_1 -> 1 ┤ √X ├┤ Rz(-2.7095) ├──■───────┤ √X ├────┤ Rz(-2.8336) ├──■──»
# «         ├────┤└┬────────────┤  │       └────┘    └─────────────┘  │  »
# «q_4 -> 2 ┤ √X ├─┤ Rz(2.1878) ├──┼──────────────────────────────────┼──»
# «         └────┘ └────────────┘┌─┴─┐┌─────────────┐               ┌─┴─┐»
# «q_0 -> 3 ─────────────────────┤ X ├┤ Rz(-0.8422) ├───────────────┤ X ├»
# «                              └───┘└─────────────┘               └───┘»
# «q_3 -> 4 ─────────────────────────────────────────────────────────────»
# «                                                                      »
# « meas_0: ═════════════════════════════════════════════════════════════»
# «                                                                      »
# « meas_1: ═════════════════════════════════════════════════════════════»
# «                                                                      »
# « meas_2: ═════════════════════════════════════════════════════════════»
# «                                                                      »
# « meas_3: ═════════════════════════════════════════════════════════════»
# «                                                                      »
# « meas_4: ═════════════════════════════════════════════════════════════»
# «                                                                      »
# «                                                                       »
# «q_2 -> 0 ──────────────────────────────────────────────────────────────»
# «              ┌────┐         ┌─────────────┐┌────┐┌─────────────┐┌────┐»
# «q_1 -> 1 ─────┤ √X ├──────■──┤ Rz(-2.4781) ├┤ √X ├┤ Rz(-1.5956) ├┤ √X ├»
# «              └────┘      │  └─────────────┘└────┘└─────────────┘└────┘»
# «q_4 -> 2 ─────────────────┼────────────────────────────────────────────»
# «         ┌─────────────┐┌─┴─┐ ┌────────────┐┌────┐┌─────────────┐┌────┐»
# «q_0 -> 3 ┤ Rz(0.24921) ├┤ X ├─┤ Rz(1.1594) ├┤ √X ├┤ Rz(-1.4542) ├┤ √X ├»
# «         └─────────────┘└───┘ └────────────┘└────┘└─────────────┘└────┘»
# «q_3 -> 4 ──────────────────────────────────────────────────────────────»
# «                                                                       »
# « meas_0: ══════════════════════════════════════════════════════════════»
# «                                                                       »
# « meas_1: ══════════════════════════════════════════════════════════════»
# «                                                                       »
# « meas_2: ══════════════════════════════════════════════════════════════»
# «                                                                       »
# « meas_3: ══════════════════════════════════════════════════════════════»
# «                                                                       »
# « meas_4: ══════════════════════════════════════════════════════════════»
# «                                                                       »
# «                                                                »
# «q_2 -> 0 ───────────────────────────────────────────────────────»
# «         ┌────────────┐┌───┐┌──────────────┐               ┌───┐»
# «q_1 -> 1 ┤ Rz(1.4854) ├┤ X ├┤ Rz(-0.88722) ├───────────────┤ X ├»
# «         └────────────┘└─┬─┘└────┬────┬────┘┌─────────────┐└─┬─┘»
# «q_4 -> 2 ────────────────■───────┤ √X ├─────┤ Rz(-2.7052) ├──■──»
# «         ┌────────────┐          ├────┤     ├─────────────┤     »
# «q_0 -> 3 ┤ Rz(1.3799) ├──■───────┤ √X ├─────┤ Rz(-2.8821) ├──■──»
# «         └────────────┘┌─┴─┐┌────┴────┴────┐└─────────────┘┌─┴─┐»
# «q_3 -> 4 ──────────────┤ X ├┤ Rz(-0.85727) ├───────────────┤ X ├»
# «                       └───┘└──────────────┘               └───┘»
# « meas_0: ═══════════════════════════════════════════════════════»
# «                                                                »
# « meas_1: ═══════════════════════════════════════════════════════»
# «                                                                »
# « meas_2: ═══════════════════════════════════════════════════════»
# «                                                                »
# « meas_3: ═══════════════════════════════════════════════════════»
# «                                                                »
# « meas_4: ═══════════════════════════════════════════════════════»
# «                                                                »
# «                                                                        »
# «q_2 -> 0 ───────────────────────────────────────────────────────────────»
# «         ┌─────────────┐ ┌───┐┌─────────────┐┌────┐┌─────────────┐┌────┐»
# «q_1 -> 1 ┤ Rz(0.57372) ├─┤ X ├┤ Rz(-1.7601) ├┤ √X ├┤ Rz(-1.4477) ├┤ √X ├»
# «         └────┬────┬───┘ └─┬─┘└┬────────────┤├────┤├─────────────┤├────┤»
# «q_4 -> 2 ─────┤ √X ├───────■───┤ Rz(3.0717) ├┤ √X ├┤ Rz(-1.4091) ├┤ √X ├»
# «              ├────┤          ┌┴────────────┤├────┤├─────────────┤├────┤»
# «q_0 -> 3 ─────┤ √X ├───────■──┤ Rz(-2.5516) ├┤ √X ├┤ Rz(-1.1379) ├┤ √X ├»
# «         ┌────┴────┴────┐┌─┴─┐├─────────────┤├────┤├─────────────┤├────┤»
# «q_3 -> 4 ┤ Rz(0.091475) ├┤ X ├┤ Rz(-1.4921) ├┤ √X ├┤ Rz(-1.3891) ├┤ √X ├»
# «         └──────────────┘└───┘└─────────────┘└────┘└─────────────┘└────┘»
# « meas_0: ═══════════════════════════════════════════════════════════════»
# «                                                                        »
# « meas_1: ═══════════════════════════════════════════════════════════════»
# «                                                                        »
# « meas_2: ═══════════════════════════════════════════════════════════════»
# «                                                                        »
# « meas_3: ═══════════════════════════════════════════════════════════════»
# «                                                                        »
# « meas_4: ═══════════════════════════════════════════════════════════════»
# «                                                                        »
# «                          ░       ┌─┐
# «q_2 -> 0 ─────────────────░───────┤M├──────
# «         ┌──────────────┐ ░       └╥┘   ┌─┐
# «q_1 -> 1 ┤ Rz(-0.62992) ├─░────────╫────┤M├
# «         ├─────────────┬┘ ░        ║ ┌─┐└╥┘
# «q_4 -> 2 ┤ Rz(-2.1129) ├──░────────╫─┤M├─╫─
# «         └┬────────────┤  ░ ┌─┐    ║ └╥┘ ║
# «q_0 -> 3 ─┤ Rz(2.7474) ├──░─┤M├────╫──╫──╫─
# «          ├────────────┤  ░ └╥┘┌─┐ ║  ║  ║
# «q_3 -> 4 ─┤ Rz(1.0325) ├──░──╫─┤M├─╫──╫──╫─
# «          └────────────┘  ░  ║ └╥┘ ║  ║  ║
# « meas_0: ════════════════════╩══╬══╬══╬══╬═
# «                                ║  ║  ║  ║
# « meas_1: ═══════════════════════╩══╬══╬══╬═
# «                                   ║  ║  ║
# « meas_2: ══════════════════════════╩══╬══╬═
# «                                      ║  ║
# « meas_3: ═════════════════════════════╩══╬═
# «                                         ║
# « meas_4: ════════════════════════════════╩═
# «

# %%
# run in real hardware
job = backend.run(optimized_circuit)
retrieved_job = backend.retrieve_job(job.job_id())
result = retrieved_job.result()
print(result.get_counts())
# Out:
# {'00000': 117, '00001': 126, '10000': 148, '10001': 142, '10010': 156, '10011': 119, '10100': 75, '10101': 90, '10110': 109, '10111': 91, '11000': 148, '11001': 144, '11010': 133, '11011': 148, '11100': 121, '11101': 82, '11110': 91, '11111': 84, '00010': 153, '00011': 180, '00100': 104, '00101': 92, '00110': 144, '00111': 112, '01000': 177, '01001': 146, '01010': 137, '01011': 157, '01100': 158, '01101': 103, '01110': 124, '01111': 89}
